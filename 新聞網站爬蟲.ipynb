# %%
# -*- coding: utf-8 -*-
import requests
from bs4 import BeautifulSoup
import re


new_list = []
url = 'https://money.udn.com/money/index'

## 1.填寫headers
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:108.0) Gecko/20100101 Firefox/108.0"}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
#print(response.text)

## 2.抓取即時區域所有新聞title以及新聞內容連結link，並將每篇新聞的連結link append到new_list內
div_tag = soup.find_all("div", {"class":"story__list story__list--web"})
for index,i in enumerate(div_tag):
    if index<=3:
        title = i.find("a")["title"].replace('','').replace('\n','')
        href_link = 'https://money.udn.com'+i.find("a")["href"]
        print('title: {}, link: {}'.format(title, href_link))
        new_list.append(href_link)
# Out:
# title: 華航63周年慶 首創台灣淨零碳飛行 並推感恩購票優惠, link: https://money.udn.com/money/story/5612/6843781?from=edn_newest_index
# title: 寒流17日報到 氣象局首發本島低溫特報, link: https://money.udn.com/money/story/7307/6843785?from=edn_newest_index
# title: PCB產業協會擬再組泰國投資考察團 明年2月出發, link: https://money.udn.com/money/story/5612/6843755?from=edn_newest_index
# title: 農友種苗印度新大樓落成 整合業務深耕市場, link: https://money.udn.com/money/story/5599/6843763?from=edn_newest_index

# %%
from time import sleep
import os
from bs4 import BeautifulSoup
from urllib.request import urlretrieve

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

        
def save_news(url):
    
    ## 3.填寫headers
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:108.0) Gecko/20100101 Firefox/108.0"}
    response = requests.get(url, headers=headers)
    sleep(1)
    
    soup = BeautifulSoup(response.text, 'html.parser')
    ## 4. 使用find_all去抓取每篇新聞的title(指定是哪個tag以及指定id)，將結果所產生之list放到new_title變數內
    new_title = soup.find_all("h1",{"id":"story_art_title"})
    save_path = './news/'+new_title[0].text.replace(':','')
    
    article_body = soup.find_all('section',{'id':'article_body'})
    print('new title: {}'.format(new_title[0].text))

    ## create folder
    createFolder(save_path)
    soup2 = BeautifulSoup(str(article_body[0]), 'html.parser')


    ## save article contens in folder
    with open(save_path+'/contents.txt', 'w', encoding='utf-8') as f:  
        ## 5. 抓取文章內p tags，並將新聞內文寫入contents.txt檔案內
        p_tags = soup2.find_all('p')
        print('new content: ')
        for i in p_tags:
            print(i.text)
            f.write(i.text)

    ## save image in article        
    
    ## 6. 抓取文章內所有img tags，並將圖片下載並存入對應新聞資料夾下
    img_tags = soup2.find_all('img')
    print('save image: ')
    for i in img_tags:
        print(i['src'])
        urlretrieve(i['src'], save_path+'/'+i['title']+'.jpg')
    print('==========\n\n')
    

for new_url in new_list:
    print(new_url)
    save_news(new_url)
# Out:
# https://money.udn.com/money/story/5612/6843781?from=edn_newest_index
# new title: 華航63周年慶 首創台灣淨零碳飛行 並推感恩購票優惠
# new content:
# 華航（2610）（2610）今 （16） 日歡慶企業營運 63 周年，同時分享 DJSI 道瓊永續指數全球航空業第一名，首創台灣「淨零碳飛行」，並推出周年慶限時優惠感恩活動，做為回饋旅客、友善地球的生日大禮。
#
#
#
